# %% [markdown]
# # Experimental GaN RTD Papers

# %%
from IPython.display import Image, HTML
import pandas as pd
pd.set_option('display.precision',2)

T=pd.DataFrame(columns=['Year','Type','Substrate','Growth','Structure',
                        'Vp','Ip','Jp','Vv','Iv','PVCR','Hyst.','Repeat.',
                        'IVFig','Group','Link'])

T.loc['Kikuchi2001'] = pd.Series({'Year':'2001',
                                  'Group':'Kishino',
                                  'Substrate':'GaN/Sap',
                                  'Type':'Planar',
                                  'Growth':'MBE',
                                  'Structure':r'GaN/AlN/GaN/AlN/GaN $\\\quad\quad$ 2/1/0.75/1/2',
                                  'Vp':2.4,'Ip':60*10**-6,
                                  'Vv':2.4,'Iv':20*10**-6,
                                  'Jp':0.93,
                                  'PVCR':3,
                                  'Hyst.':'?',
                                  'Repeat.':'?',
                                  'IVFig':'./Figs/Kikuchi2001.png',
                                  'Link':'http://doi.wiley.com/10.1002/1521-396X(200111)188:1%3C187::AID-PSSA187%3E3.0.CO;2-5'})

T.loc['Kikuchi2002'] = pd.Series({'Year':'2002',
                                  'Group':'Kishino',
                                  'Substrate':'GaN/Sap',
                                  'Type':'Planar',
                                  'Growth':'MBE',
                                  'Structure':r'GaN/AlN/GaN/AlN/GaN $\\\quad\quad$ 2/1/0.75/1/2',
                                  'Vp':2.4,'Ip':2.9*10**-3,
                                  'Vv':2.4,'Iv':2.9*10**-3/32,
                                  'Jp':180,
                                  'PVCR':32,
                                  'Hyst.':'?',
                                  'Repeat.':'?',
                                  'IVFig':'./Figs/Kikuchi2002.png',
                                  'Link':'http://scitation.aip.org/content/aip/journal/apl/81/9/10.1063/1.1501157'})

T.loc['Foxon2003'] = pd.Series({'Year':'2003',
                                  'Group':'Humphreys',
                                  'Substrate':'GaN/Sap',
                                  'Type':'Planar',
                                  'Growth':'MBE',
                                  'Structure':r'AlN/GaN/AlN $\\\quad\quad$ 2/2/1',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'',
                                  'Hyst.':'Yes',
                                  'Repeat.':'No',
                                  'IVFig':'./Figs/Foxon2003.png',
                                  'Link':'http://doi.wiley.com/10.1002/pssc.200303376'})

T.loc['Hermann2004'] = pd.Series({'Year':'2004',
                                  'Group':'Eickhoff',
                                  'Substrate':'GaN/Sap',
                                  'Type':'Planar',
                                  'Growth':'MBE',
                                  'Structure':r'AlN/GaN/AlN $\\\quad\quad\quad$ 3/6/3',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'8.3',
                                  'Hyst.':'No',
                                  'Repeat.':'No',
                                  'IVFig':'./Figs/Hermann2004.png',
                                  'Link':'http://doi.wiley.com/10.1002/pssc.200404771'})

T.loc['Belyaev2004'] = pd.Series({'Year':'2004',
                                  'Group':'Humphreys',
                                  'Substrate':'GaN/Sap',
                                  'Type':'Planar',
                                  'Growth':'MBE',
                                  'Structure':r'AlN/GaN/AlN $\\\quad\quad\quad$ 2/2/1',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'',
                                  'Hyst.':'Yes',
                                  'Repeat.':'No',
                                  'IVFig':'./Figs/Belyaev2004.png',
                                  'Link':'http://linkinghub.elsevier.com/retrieve/pii/S1386947703006878'})

T.loc['Golka2006'] = pd.Series({'Year':'2006',
                                  'Group':'Strasser',
                                  'Substrate':'GaN',
                                  'Type':'Planar',
                                  'Growth':'MBE',
                                  'Structure':r'Al$_{0.7}$GaN/GaN/Al$_{0.7}$GaN $\\\quad\quad$ 2/2/2',
                                  'Vp':2.2,'Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':10*10**3,
                                  'PVCR':'',
                                  'Hyst.':'Yes',
                                  'Repeat.':'No',
                                  'IVFig':'./Figs/Golka2006.png',
                                  'Link':'http://scitation.aip.org/content/aip/journal/apl/88/17/10.1063/1.2199445'})

T.loc['Kurakin2006'] = pd.Series({'Year':'2006',
                                  'Group':'Belyaev',
                                  'Substrate':'GaN/Sap',
                                  'Type':'Planar',
                                  'Growth':'MBE',
                                  'Structure':r'AlN/GaN/AlN $\\\\$ 2/2/2',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'',
                                  'Hyst.':'?',
                                  'Repeat.':'No',
                                  'IVFig':'./Figs/Kurakin2006.png',
                                  'Link':'http://doi.wiley.com/10.1002/pssc.200565156'})

T.loc['Leconte2008'] = pd.Series({'Year':'2008',
                                  'Group':'Monroy',
                                  'Substrate':'GaN/Sap',
                                  'Type':'Planar',
                                  'Growth':'MBE',
                                  'Structure':r'GaN/AlN/GaN/AlN/GaN $\\\\$ 10/0.5/0.5/0.5/10',
                                  'Vp':1.5,'Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':3.2,
                                  'Hyst.':'Yes',
                                  'Repeat.':'No',
                                  'IVFig':'./Figs/Leconte2008.png',
                                  'Link':'http://doi.wiley.com/10.1002/pssc.200777463'})

T.loc['Bayram2010'] = pd.Series({'Year':'2010',
                                  'Group':'Razeghi',
                                  'Substrate':'LEO-GaN',
                                  'Type':'Planar',
                                  'Growth':'MOCVD',
                                  'Structure':r'GaN/AlN/GaN/AlN/GaN $\\\\$ 2/1/0.8/1/2',
                                  'Vp':4.7,'Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':5.9*10**3,
                                  'PVCR':1.6,
                                  'Hyst.':'Yes',
                                  'Repeat.':'No',
                                  'IVFig':'./Figs/Bayram2010.png',
                                  'Link':'http://scitation.aip.org/content/aip/journal/apl/97/9/10.1063/1.3484280'})

T.loc['Bayram2010B'] = pd.Series({'Year':'2010',
                                  'Group':'Razeghi',
                                  'Substrate':'LEO-GaN and GaN',
                                  'Type':'Planar',
                                  'Growth':'MOCVD',
                                  'Structure':r'GaN/Al$_{0.2}$GaN/GaN/Al$_{0.2}$GaN/GaN $\\\\$ 2/1.5/1.25/1.5/2',
                                  'Vp':4.7,'Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':5.9*10**3,
                                  'PVCR':1.6,
                                  'Hyst.':'Yes',
                                  'Repeat.':'No',
                                  'IVFig':'./Figs/Bayram2010B.png',
                                  'Link':'http://scitation.aip.org/content/aip/journal/apl/97/18/10.1063/1.3515418'})

T.loc['Songmuang2010'] = pd.Series({'Year':'2010',
                                  'Group':'De Franceschi',
                                  'Substrate':'Si(111)',
                                  'Type':'Nanowire',
                                  'Growth':'MBE',
                                  'Structure':r'AlN/GaN/AlN $\\\\$ 2/6/2',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'1.5(4.2K)',
                                  'Hyst.':'No',
                                  'Repeat.':'Yes',
                                  'IVFig':'./Figs/Songmuang2010.png',
                                  'Link':'http://www.ncbi.nlm.nih.gov/pubmed/20731363'})

T.loc['Rigutti2010'] = pd.Series({'Year':'2010',
                                  'Group':'Tchernycheva',
                                  'Substrate':'Si(111)',
                                  'Type':'Nanowire',
                                  'Growth':'MOCVD',
                                  'Structure':r'AlN/GaN/AlN $\\\\$ 3/1.6/3',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'1.05(77K)',
                                  'Hyst.':'Weak',
                                  'Repeat.':'Yes',
                                  'IVFig':'./Figs/Rigutti2010.png',
                                  'Link':'http://www.ncbi.nlm.nih.gov/pubmed/20864782'})


T.loc['Vashaei2010'] = pd.Series({'Year':'2010',
                                  'Group':'Razeghi',
                                  'Substrate':'LEO-GaN and GaN',
                                  'Type':'Planar',
                                  'Growth':'MOCVD',
                                  'Structure':r'GaN/AlN/GaN/AlN/GaN $\\\\$ 2/1/0.8/1/2',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'2.15(LEO) 1.42(GaN-temp)',
                                  'Hyst.':'?',
                                  'Repeat.':'?',
                                  'IVFig':'./Figs/Vashaei2010.png',
                                  'Link':'http://scitation.aip.org/content/aip/journal/jap/107/8/10.1063/1.3372763'})

T.loc['Bayram2010C'] = pd.Series({'Year':'2010',
                                  'Group':'Razeghi',
                                  'Substrate':'c-GaN and m-GaN',
                                  'Type':'Planar',
                                  'Growth':'MOCVD',
                                  'Structure':r'GaN/Al$_{0.2}$GaN/GaN/Al$_{0.2}$GaN/GaN $\\\\$ 2/1.5/1.25/1.5/2',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'',
                                  'Hyst.':'?',
                                  'Repeat.':'No',
                                  'IVFig':'./Figs/Bayram2010C.png',
                                  'Link':'http://scitation.aip.org/content/aip/journal/apl/96/4/10.1063/1.3294633'})

T.loc['Li2012'] = pd.Series({'Year':'2012',
                                  'Group':'Malis',
                                  'Substrate':'GaN',
                                  'Type':'Planar',
                                  'Growth':'MBE',
                                  'Structure':r'GaN/Al$_{0.18}$GaN/GaN/Al$_{0.18}$GaN/GaN $\\\\$ 2/2.4/2.4/2.4/2',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'1.03(77K)',
                                  'Hyst.':'No',
                                  'Repeat.':'Yes',
                                  'IVFig':'./Figs/Li2012.png',
                                  'Link':'http://scitation.aip.org/content/aip/journal/apl/100/25/10.1063/1.4729819'})


T.loc['Carnevale2012'] = pd.Series({'Year':'2012',
                                  'Group':'Meyers',
                                  'Substrate':'Si(111)',
                                  'Type':'Nanowire',
                                  'Growth':'MBE',
                                  'Structure':r'AlN/GaN/AlN $\\\\$ 1.5/2.5/1.5',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'2.4',
                                  'Hyst.':'Yes',
                                  'Repeat.':'No',
                                  'IVFig':'./Figs/Carnevale2012.png',
                                  'Link':'http://aip.scitation.org/doi/10.1063/1.3701586'})


T.loc['Li2013'] = pd.Series({'Year':'2013',
                                  'Group':'Malis',
                                  'Substrate':'GaN',
                                  'Type':'Planar',
                                  'Growth':'MBE',
                                  'Structure':r'GaN/Al$_{0.35}$GaN/GaN/Al$_{0.35}$GaN/GaN $\\\\$ 2/2.4/2.4/2.4/2',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'?',
                                  'Hyst.':'Yes',
                                  'Repeat.':'Yes',
                                  'IVFig':'./Figs/LiLi2013.png',
                                  'Link':'http://stacks.iop.org/0268-1242/28/i=7/a=074024?key=crossref.2db1ad6b6371ceb820a4ace3ac6141aa'})

T.loc['Shao2013'] = pd.Series({'Year':'2013',
                                  'Group':'Mayers',
                                  'Substrate':'Si(111)',
                                  'Type':'Nanowire',
                                  'Growth':'MBE',
                                  'Structure':r'AlN/GaN/AlN $\\\\$ 1.5/2.5/1.5',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'?',
                                  'Hyst.':'?',
                                  'Repeat.':'No',
                                  'IVFig':'./Figs/ShaoShao2013.png',
                                  'Link':'http://scitation.aip.org/content/avs/journal/jvstb/31/6/10.1116/1.4829432'})

T.loc['Egorkin2014'] = pd.Series({'Year':'2014',
                                  'Group':'Zhuravlev',
                                  'Substrate':'GaN/Sap',
                                  'Type':'Planar',
                                  'Growth':'MBE',
                                  'Structure':r'GaN/AlN/GaN/AlN/GaN $\\\quad\quad\quad$ ?/1/2/1/?',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'1.2',
                                  'Hyst.':'Yes',
                                  'Repeat.':'Yes',
                                  'IVFig':'./Figs/Egorkin2014.png',
                                  'Link':'http://link.springer.com/10.1134/S1063782614130041'})

T.loc['Malis2014'] = pd.Series({'Year':'2014',
                                  'Group':'Malis',
                                  'Substrate':'GaN',
                                  'Type':'Planar',
                                  'Growth':'MBE',
                                  'Structure':r'Al$_{0.2}$GaN/GaN/Al$_{0.2}$GaN $\\\quad\quad\quad$ ?/4.9/?',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'1.4(77K)',
                                  'Hyst.':'?',
                                  'Repeat.':'?',
                                  'IVFig':'./Figs/Malis2014.png',
                                  'Link':'http://proceedings.spiedigitallibrary.org/proceeding.aspx?articleid=1838106'})


T.loc['Nagase2014'] = pd.Series({'Year':'2014',
                                  'Group':'Nagase',
                                  'Substrate':'GaN/Sap',
                                  'Type':'Planar',
                                  'Growth':'MBE',
                                  'Structure':r'GaN/AlN/GaN/AlGaN/GaN $\\\quad\quad\quad$ 3/2/2.5/2/3',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'13',
                                  'Hyst.':'Yes',
                                  'Repeat.':'No',
                                  'IVFig':'./Figs/Nagase2014.png',
                                  'Link':'http://ieeexplore.ieee.org/lpdocs/epic03/wrapper.htm?arnumber=6783796'})

T.loc['Nagase2015'] = pd.Series({'Year':'2015',
                                  'Group':'Nagase',
                                  'Substrate':'GaN/Sap',
                                  'Type':'Planar',
                                  'Growth':'MOCVD',
                                  'Structure':r'GaN/AlN/GaN/AlGaN/GaN $\\\quad\quad\quad$ 3/2/2.5/2/3',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'',
                                  'Hyst.':'Yes',
                                  'Repeat.':'No',
                                  'IVFig':'./Figs/Nagase2015.png',
                                  'Link':'http://stacks.iop.org/1347-4065/54/i=3/a=034201?key=crossref.25de01b5c372b4122f30fefa2ed3615a'})

T.loc['Growden2016'] = pd.Series({'Year':'2016',
                                  'Group':'Berger',
                                  'Substrate':'GaN',
                                  'Type':'Planar',
                                  'Growth':'MBE',
                                  'Structure':r'GaN/AlN/GaN/AlGaN/GaN $\\\quad\quad\quad$ 12/2/3/2/6',
                                  'Vp':'','Ip':'',
                                  'Vv':'','Iv':'',
                                  'Jp':'',
                                  'PVCR':'1.07(297K) 1.12(20K)',
                                  'Hyst.':'No',
                                  'Repeat.':'Yes',
                                  'IVFig':'./Figs/Growden2016.png',
                                  'Link':'http://scitation.aip.org/content/aip/journal/apl/109/8/10.1063/1.4961442'})

def path_to_image_html(path):
    return '<img src="'+ path + '"/>'

def link_html(link):
    return '<a href="'+ link + '">link</a>'

#pd.set_option('display.max_colwidth',31)

#HTML(T.to_html(escape=False ,formatters=dict(IV=path_to_image_html,Link=link_html)))

pd.set_option('display.max_colwidth', -1)

#HTML(T[['Year','Type','Substrate','Growth','Structure','PVCR','Hyst.','Repeat.',
#        'IVFig','Group']].to_html(escape=False ,formatters=dict(IVFig=path_to_image_html)))
HTML(T[['Year','Type','Substrate','Growth','Structure','PVCR','Hyst.','Repeat.',
        'IVFig','Group','Link']].to_html(index=False,escape=False ,formatters=dict(IVFig=path_to_image_html,Link=link_html)))
#HTML(T.to_html(escape=False ,formatters=dict(IVFig=path_to_image_html)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Year</th>
#       <th>Type</th>
#       <th>Substrate</th>
#       <th>Growth</th>
#       <th>Structure</th>
#       <th>PVCR</th>
#       <th>Hyst.</th>
#       <th>Repeat.</th>
#       <th>IVFig</th>
#       <th>Group</th>
#       <th>Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2001</td>
#       <td>Planar</td>
#       <td>GaN/Sap</td>
#       <td>MBE</td>
#       <td>GaN/AlN/GaN/AlN/GaN $\\\quad\quad$ 2/1/0.75/1/2</td>
#       <td>3</td>
#       <td>?</td>
#       <td>?</td>
#       <td><img src="./Figs/Kikuchi2001.png"/></td>
#       <td>Kishino</td>
#       <td><a href="http://doi.wiley.com/10.1002/1521-396X(200111)188:1%3C187::AID-PSSA187%3E3.0.CO;2-5">link</a></td>
#     </tr>
#     <tr>
#       <td>2002</td>
#       <td>Planar</td>
#       <td>GaN/Sap</td>
#       <td>MBE</td>
#       <td>GaN/AlN/GaN/AlN/GaN $\\\quad\quad$ 2/1/0.75/1/2</td>
# ...
