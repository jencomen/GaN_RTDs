# %% [markdown]
# # Theoretical GaN RTD Papers

# %%
from IPython.display import Image, HTML
import pandas as pd
pd.set_option('display.precision',2)

NR='Not reported'
T=pd.DataFrame(columns=['Year','Method','Structure','BD','IV_r',
                        'IV_f','PVCR','Group','Link'])

T.loc['Sacconi2002'] = pd.Series({'Year':'2001',
                                  'Group':'Lugli',
                                  'Method':'Tight-Binding and Transfer Matrix',
                                  'Structure':'GaN/AlN/GaN/AlN/GaN 1.5/3/3/3/1.5',
                                  'BD':'./Figs/Sacconi_BD.png','IV_r':'',
                                  'IV_f':'./Figs/Sacconi_IV_f.png',
                                  'PVCR':NR,
                                  'Link':'http://doi.wiley.com/10.1002/1521-396X%28200203%29190%3A1%3C295%3A%3AAID-PSSA295%3E3.0.CO%3B2-A'})

T.loc['Indlekofer2002'] = pd.Series({'Year':'2002',
                                  'Group':'Indlekofer',
                                  'Method':"Tight-Binding Green's Function",
                                  'Structure':'AlN/GaN/AlN 1/0.75/1',
                                  'BD':'./Figs/Indlekofer_BD.png','IV_r':'',
                                  'IV_f':'./Figs/Indlekofer_IV_f.png',
                                  'PVCR':NR,
                                  'Link':'http://doi.wiley.com/10.1002/1521-3951%28200212%29234%3A3%3C769%3A%3AAID-PSSB769%3E3.0.CO%3B2-H'})

T.loc['Grinyaev2003'] = pd.Series({'Year':'2003',
                                  'Group':'',
                                  'Method':'Pseudopotential Method and Transfer Matrix',
                                  'Structure':'AlN/GaN/AlN 1/2.5/1',
                                  'BD':'','IV_r':'',
                                  'IV_f':'./Figs/Grinyaev_IV_f.png',
                                  'PVCR':NR,
                                  'Link':'http://www.springerlink.com/index/10.1134/1.1568463'})

T.loc['Hermann2004'] = pd.Series({'Year':'2004',
                                  'Group':'Eickhoff',
                                  'Method':"Tight-Binding Green's Function",
                                  'Structure':'AlN/GaN/AlN 2/2/1',
                                  'BD':'./Figs/Hermann_BD.png','IV_r':'',
                                  'IV_f':'./Figs/Hermann_IV_f.png',
                                  'PVCR':NR,
                                  'Link':'http://doi.wiley.com/10.1002/pssc.200404771'})

T.loc['Yang2011'] = pd.Series({'Year':'2011',
                                  'Group':'Hao',
                                  'Method':"Silvaco Simulator",
                                  'Structure':r'Al$_{0.2}$GaN/GaN/Al$_{0.2}$GaN 2/2/2',
                                  'BD':'','IV_r':'',
                                  'IV_f':'./Figs/Yang_IV_f.png',
                                  'PVCR':NR,
                                  'Link':'http://scitation.aip.org/content/aip/journal/apl/99/15/10.1063/1.3650253'})

T.loc['Sakr2011'] = pd.Series({'Year':'2011',
                                  'Group':'Julien',
                                  'Method':"NextNANO and Transfer Matrix",
                                  'Structure':r'GaN/Al$_{0.5}$GaN/GaN/Al$_{0.5}$GaN/GaN 5/1/2/1/5',
                                  'BD':'./Figs/Sakr_BD.png','IV_r':'./Figs/Sakr_IV_r.png',
                                  'IV_f':'./Figs/Sakr_IV_f.png',
                                  'PVCR':NR,
                                  'Link':'http://scitation.aip.org/content/aip/journal/jap/109/2/10.1063/1.3533975'})

T.loc['Boucherit2012'] = pd.Series({'Year':'2012',
                                  'Group':'DeJaeger',
                                  'Method':"NEGF",
                                  'Structure':r'GaN/AGaN/GaN/AlGaN/GaN 1/1/1/1/1',
                                  'BD':'./Figs/Boucherit_BD.png','IV_r':'',
                                  'IV_f':'./Figs/Boucherit_IV_f.png',
                                  'PVCR':NR,
                                  'Link':'http://scitation.aip.org/content/aip/journal/jap/112/11/10.1063/1.4767382'})

T.loc['Chen2013'] = pd.Series({'Year':'2013',
                                  'Group':'Hao',
                                  'Method':"NEGF-Silvaco",
                                  'Structure':r'In$_{0.17}$AlN/GaN/In$_{0.17}$AlN',
                                  'BD':'./Figs/Chen_BD.png','IV_r':'',
                                  'IV_f':'./Figs/Chen_IV_f.png',
                                  'PVCR':NR,
                                  'Link':'http://scitation.aip.org/content/aip/journal/jap/113/19/10.1063/1.4804414'})

T.loc['Chen2014'] = pd.Series({'Year':'2014',
                                  'Group':'Hao',
                                  'Method':"NEGF-Silvaco",
                                  'Structure':r'In$_{0.05}$GaN/In$_{0.17}$AlN/GaN/In$_{0.17}$AlN',
                                  'BD':'./Figs/Chen2014_BD.png','IV_r':'',
                                  'IV_f':'./Figs/Chen2014_IV_f.png',
                                  'PVCR':NR,
                                  'Link':'http://scitation.aip.org/content/aip/journal/jap/116/7/10.1063/1.4893561'})

T.loc['Grier2015'] = pd.Series({'Year':'2015',
                                  'Group':'Harrison',
                                  'Method':"Density Matrix",
                                  'Structure':r'GaN/Al$_{0.18}$GaN/GaN/Al$_{0.18}$GaN/GaN 2/2.9/4.9/2.9/2',
                                  'BD':'./Figs/Grier_BD.png','IV_r':'',
                                  'IV_f':'./Figs/Grier_IV_f.png',
                                  'PVCR':NR,
                                  'Link':'http://dx.doi.org/10.1063/1.4936962'})

T.loc['Bhouri2015'] = pd.Series({'Year':'2015',
                                  'Group':'Lazzari',
                                  'Method':"Transfer Matrix",
                                  'Structure':r'GaN/Al$_{0.5}$GaN/GaN/Al$_{0.5}$GaN/In$_{0.1}$GaN 5/1/2/1/6',
                                  'BD':'./Figs/Bhouri_BD.png','IV_r':'',
                                  'IV_f':'./Figs/Bhouri_IV_f.png',
                                  'PVCR':NR,
                                  'Link':'http://stacks.iop.org/0022-3727/48/i=38/a=385102?key=crossref.823d372d86cba8f25e4c9dbc381588c6'})

T.loc['Rached2016'] = pd.Series({'Year':'2016',
                                  'Group':'Lazzari',
                                  'Method':"Transfer Matrix",
                                  'Structure':r'GaN/Al$_{0.5}$GaN/GaN/Al$_{0.5}$GaN/GaN 5/1/2/1/5',
                                  'BD':'./Figs/Rached_BD.png','IV_r':'',
                                  'IV_f':'./Figs/Rached_IV_f.png',
                                  'PVCR':NR,
                                  'Link':'http://linkinghub.elsevier.com/retrieve/pii/S0749603615303372'})

T.loc['Yang2016'] = pd.Series({'Year':'2016',
                                  'Group':'Hao',
                                  'Method':"NEGF-Silvaco",
                                  'Structure':r'GaN/Al$_{0.5}$GaN/GaN/Al$_{0.5}$GaN/GaN 5/1/2/1/5',
                                  'BD':'','IV_r':'',
                                  'IV_f':'./Figs/Yang_IV_f.png',
                                  'PVCR':NR,
                                  'Link':'http://linkinghub.elsevier.com/retrieve/pii/S0749603615303372'})


def path_to_image_html(path):
    return '<img src="'+ path + '"/>'

def link_html(link):
    return '<a href="'+ link + '">link</a>'

#pd.set_option('display.max_colwidth',31)

#HTML(T.to_html(escape=False ,formatters=dict(IV=path_to_image_html,Link=link_html)))

pd.set_option('display.max_colwidth', -1)

#HTML(T[['Year','Type','Substrate','Growth','Structure','PVCR','Hyst.','Repeat.',
#        'IVFig','Group']].to_html(escape=False ,formatters=dict(IVFig=path_to_image_html)))
#HTML(T[['Year','Type','Substrate','Growth','Structure','PVCR','Hyst.','Repeat.',
#        'IVFig','Group','Link']].to_html(index=False,escape=False ,formatters=dict(IVFig=path_to_image_html,Link=link_html)))
HTML(T[['Year','Method','Structure','BD','IV_r',
                        'IV_f','Group','Link']].to_html(index=False,escape=False,
               formatters=dict(BD=path_to_image_html,IV_r=path_to_image_html,IV_f=path_to_image_html,
                                Link=link_html)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Year</th>
#       <th>Method</th>
#       <th>Structure</th>
#       <th>BD</th>
#       <th>IV_r</th>
#       <th>IV_f</th>
#       <th>Group</th>
#       <th>Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2001</td>
#       <td>Tight-Binding and Transfer Matrix</td>
#       <td>GaN/AlN/GaN/AlN/GaN 1.5/3/3/3/1.5</td>
#       <td><img src="./Figs/Sacconi_BD.png"/></td>
#       <td><img src=""/></td>
#       <td><img src="./Figs/Sacconi_IV_f.png"/></td>
#       <td>Lugli</td>
#       <td><a href="http://doi.wiley.com/10.1002/1521-396X%28200203%29190%3A1%3C295%3A%3AAID-PSSA295%3E3.0.CO%3B2-A">link</a></td>
#     </tr>
#     <tr>
#       <td>2002</td>
#       <td>Tight-Binding Green's Function</td>
#       <td>AlN/GaN/AlN 1/0.75/1</td>
#       <td><img src="./Figs/Indlekofer_BD.png"/></td>
#       <td><img src=""/></td>
# ...
